# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exploratory Data Analysis (EDA) - Bar Chart 10 Most Brand
df = pd.read_csv("Automobile.csv")

# Extract 'merk' (brand) from the first word of the 'name' column
df['merk'] = df['name'].str.split().str[0]

# Count Occurences
top_context = df['merk'].value_counts().head(10) 

# Bar Chart
plt.figure(figsize=(10, 6))
ax = top_context.plot(kind='bar')
# Add label
for i, value in enumerate(top_context):
    plt.text(i, value + 1, str(value), ha='center', va='bottom')
plt.title("10 Most Brand")
plt.xlabel("Brand")
plt.ylabel("Number of Car")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exploratory Data Analysis (EDA) - Top 10 Brands by Highest Average Horsepower
df = pd.read_csv("Automobile.csv")

# Extract 'merk' (brand) from the first word of the 'name' column
df['merk'] = df['name'].str.split().str[0]

# Convert 'horsepower' to numeric and clean empty value
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df = df.dropna(subset=['horsepower'])

# Group by brand
max_hp_per_brand = df.loc[df.groupby('merk')['horsepower'].idxmax()]

# Get top 10 brands by highest horsepower
top_hp_brands = max_hp_per_brand.sort_values(by='horsepower', ascending=False).head(10)

# Bar Chart
plt.figure(figsize=(10, 6))
ax = plt.bar(top_hp_brands['merk'], top_hp_brands['horsepower'])
# Add label
for i, value in enumerate(top_hp_brands['horsepower']):
    plt.text(i, value + 2, f"{value:.0f}", ha='center', va='bottom')
plt.title("Top 10 Brands by Highest Average Horsepower")
plt.xlabel("Brand")
plt.ylabel("Horsepower")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exploratory Data Analysis (EDA) - Top 10 Brands by Highest Average Weight
df = pd.read_csv("Automobile.csv")

# Extract 'merk' (brand) from the first word of the 'name' column
df['merk'] = df['name'].str.split().str[0]

# Convert 'weight' to numeric and clean empty value
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')
df = df.dropna(subset=['weight'])

# Group by brand
max_hp_per_brand = df.loc[df.groupby('merk')['weight'].idxmax()]

# Get top 10 brands by highest weight
top_hp_brands = max_hp_per_brand.sort_values(by='weight', ascending=False).head(10)

# Bar Chart
plt.figure(figsize=(10, 6))
ax = plt.bar(top_hp_brands['merk'], top_hp_brands['weight'])
# Add label
for i, value in enumerate(top_hp_brands['weight']):
    plt.text(i, value + 2, f"{value:.0f}", ha='center', va='bottom')
plt.title("Top 10 Brands by Highest Average Weight")
plt.xlabel("Brand")
plt.ylabel("Weight")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exploratory Data Analysis (EDA) - Top 10 Brands by Fastest Average Acceleration
df = pd.read_csv("Automobile.csv")

# Extract 'merk' (brand) from the first word of the 'name' column
df['merk'] = df['name'].str.split().str[0]

# Convert 'acceleration' to numeric and clean empty value
df['acceleration'] = pd.to_numeric(df['acceleration'], errors='coerce')
df = df.dropna(subset=['acceleration'])

# Group by brand
max_hp_per_brand = df.loc[df.groupby('merk')['acceleration'].idxmax()]

# Get top 10 brands by highest acceleration
top_hp_brands = max_hp_per_brand.sort_values(by='acceleration', ascending=True).head(10)

# Bar Chart
plt.figure(figsize=(10, 6))
ax = plt.bar(top_hp_brands['merk'], top_hp_brands['acceleration'])
# Add label
for i, value in enumerate(top_hp_brands['acceleration']):
    plt.text(i, value + 2, f"{value:.0f}", ha='center', va='bottom')
plt.title("Top 10 Brands by Fastest Average Acceleration")
plt.xlabel("Brand")
plt.ylabel("Acceleration")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exploratory Data Analysis (EDA) - Top 10 Brands by Highest Average Displacement
df = pd.read_csv("Automobile.csv")

# Extract 'merk' (brand) from the first word of the 'name' column
df['merk'] = df['name'].str.split().str[0]

# Convert 'displacement' to numeric and clean empty value
df['displacement'] = pd.to_numeric(df['displacement'], errors='coerce')
df = df.dropna(subset=['displacement'])

# Group by brand
max_displacement_per_brand = df.loc[df.groupby('merk')['displacement'].idxmax()]

# Get top 10 brands by highest average displacement
top_displacement_brands = max_displacement_per_brand.sort_values(by='displacement', ascending=False).head(10)

# Bar Chart
plt.figure(figsize=(10, 6))
ax = plt.bar(top_displacement_brands['merk'], top_displacement_brands['displacement'])
# Add label
for i, value in enumerate(top_displacement_brands['displacement']):
    plt.text(i, value + 2, f"{value:.0f}", ha='center', va='bottom')
plt.title("Top 10 Brands by Highest Average Displacement")
plt.xlabel("Brand")
plt.ylabel("Displacement")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exploratory Data Analysis (EDA) - Top 10 Brands by Average Lowest Fuel Efficient
df = pd.read_csv("Automobile.csv")

# Extract 'merk' (brand) from the first word of the 'name' column
df['merk'] = df['name'].str.split().str[0]

# Convert 'mpg' to numeric and clean empty value
df['mpg'] = pd.to_numeric(df['mpg'], errors='coerce')
df = df.dropna(subset=['mpg'])

# Group by brand
max_hp_per_brand = df.loc[df.groupby('merk')['mpg'].idxmax()]

# Get top 10 brands by highest mpg
top_hp_brands = max_hp_per_brand.sort_values(by='mpg', ascending=True).head(10)

# Bar Chart
plt.figure(figsize=(10, 6))
ax = plt.bar(top_hp_brands['merk'], top_hp_brands['mpg'])
# Add label
for i, value in enumerate(top_hp_brands['mpg']):
    plt.text(i, value + 2, f"{value:.0f}", ha='center', va='bottom')
plt.title("Top 10 Brands by Average Lowest Fuel Efficient")
plt.xlabel("Brand")
plt.ylabel("Mpg")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exploratory Data Analysis (EDA) - Stacked Bar Chart per Origin by Vehicle Weight Category
df = pd.read_csv("Automobile.csv")

# Convert 'weight' to numeric and clean empty value
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')
df = df.dropna(subset=['weight'])

# Create weight categories
bins = [1000, 2000, 3000, float('inf')]
labels = ['Low (1000-2000)', 'Med (2001-3000)', 'High (3000>)']
df['weight_category'] = pd.cut(df['weight'], bins=bins, labels=labels, right=True, include_lowest=True)

# Group by origin and weight category
grouped = df.groupby(['origin', 'weight_category'], observed=False).size().unstack(fill_value=0)

# Stacked Bar Chart
plt.figure(figsize=(10, 6))
bottom = pd.Series([0] * len(grouped), index=grouped.index)
for category in labels:
    values = grouped[category] if category in grouped.columns else pd.Series([0] * len(grouped), index=grouped.index)
    bars = plt.bar(grouped.index, values, bottom=bottom, label=category)
    # Add value label in center of each segment
    for i, value in enumerate(values):
        if value > 0:
            plt.text(i, bottom.iloc[i] + value / 2, f"{int(value)}", ha='center', va='center', color='white', fontsize=9)
    bottom += values
plt.title("Vehicle Weight Category Distribution per Origin")
plt.xlabel("Origin")
plt.ylabel("Count")
plt.legend(title="Weight Category")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exploratory Data Analysis (EDA) - Stacked Bar Chart per Origin by Vehicle Horsepower Category
df = pd.read_csv("Automobile.csv")

# Convert 'horsepower' to numeric and clean empty value
df['horsepower'] = pd.to_numeric(df['horsepower'], errors='coerce')
df = df.dropna(subset=['horsepower'])

# Create horsepower categories
bins = [0, 75, 150, float('inf')]
labels = ['Low (0-75)', 'Med (76-150)', 'High (150+)']
df['horsepower_category'] = pd.cut(df['horsepower'], bins=bins, labels=labels, right=True, include_lowest=True)

# Group by origin and horsepower category
grouped = df.groupby(['origin', 'horsepower_category'], observed=False).size().unstack(fill_value=0)

# Stacked Bar Chart
plt.figure(figsize=(10, 6))
bottom = pd.Series([0] * len(grouped), index=grouped.index)
for category in labels:
    values = grouped[category] if category in grouped.columns else pd.Series([0] * len(grouped), index=grouped.index)
    bars = plt.bar(grouped.index, values, bottom=bottom, label=category)
    # Add value label in center of each segment
    for i, value in enumerate(values):
        if value > 0:
            plt.text(i, bottom.iloc[i] + value / 2, f"{int(value)}", ha='center', va='center', color='white', fontsize=9)
    bottom += values
plt.title("Vehicle Horsepower Category Distribution per Origin")
plt.xlabel("Origin")
plt.ylabel("Count")
plt.legend(title="Horsepower Category")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Exploratory Data Analysis (EDA) - Stacked Bar Chart per Origin by Vehicle Fuel Consumption (Mpg) Category
df = pd.read_csv("Automobile.csv")

# Convert mpg to numeric and clean
df['mpg'] = pd.to_numeric(df['mpg'], errors='coerce')
df = df.dropna(subset=['mpg'])

# Create MPG categories
bins = [0, 20, 30, float('inf')]
labels = ['Low MPG (<20)', 'Medium MPG (20–30)', 'High MPG (>30)']

df['mpg_category'] = pd.cut(
    df['mpg'],
    bins=bins,
    labels=labels,
    right=False
)

# Group by origin and mpg category
grouped = df.groupby(['origin', 'mpg_category'], observed=False).size().unstack(fill_value=0)

# Stacked bar chart
plt.figure(figsize=(10, 6))
bottom = pd.Series([0] * len(grouped), index=grouped.index)
for category in labels:
    values = grouped[category] if category in grouped.columns else pd.Series([0] * len(grouped), index=grouped.index)
    plt.bar(grouped.index, values, bottom=bottom, label=category)
    # value labels
    for i, value in enumerate(values):
        if value > 0:
            plt.text(i, bottom.iloc[i] + value/2, int(value),
                     ha='center', va='center', color='white', fontsize=9)
    bottom += values
plt.title("Vehicle Fuel Efficiency (MPG) Distribution per Origin")
plt.xlabel("Origin")
plt.ylabel("Count")
plt.legend(title="MPG Category")
plt.tight_layout()
plt.show()
